# %% [markdown]
# # Project 1- DC Properites

# %%
#import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Insert Data

# %%
#load csv file data with headers
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location, low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.shape
# Out:
# (158957, 49)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#descriptive statistics
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
#doesn't do anything on its own
df.groupby('WARD')

# %%
#add a stats or math function to it
df['PRICE'].groupby(df['WARD']).mean()
# Out:
# WARD
# Ward 1    5.738363e+05
# Ward 2    1.098570e+06
# Ward 3    3.077716e+06
# Ward 4    4.899224e+05
# Ward 5    3.952432e+05
# Ward 6    5.268684e+05
# Ward 7    2.339222e+05
# Ward 8    2.715224e+05
# Name: PRICE, dtype: float64

# %%
#use two columns to groupby
df.groupby(['BEDRM', 'SALEDATE','PRICE']).mean()
# Out:
#                                       Unnamed: 0  BATHRM  HF_BATHRM  \
# BEDRM SALEDATE            PRICE
# 0     1992-01-21 00:00:00 50000.0       137227.0     1.0        0.0
#       1992-02-24 00:00:00 42000.0       115520.0     1.0        0.0
#       1992-03-05 00:00:00 48500.0       107700.0     1.0        0.0
#       1992-03-11 00:00:00 48900.0       147569.0     1.0        0.0
#       1992-04-06 00:00:00 55000.0       118969.0     1.0        0.0
#                           60000.0       119096.5     1.0        0.0
#                           75000.0       152211.0     1.0        0.0
#       1992-05-05 00:00:00 45000.0       152003.0     1.0        0.0
#       1992-05-19 00:00:00 28000.0       122087.0     1.0        0.0
#       1992-06-29 00:00:00 66000.0        97523.0     1.0        0.0
#       1992-06-30 00:00:00 53500.0       119368.0     1.0        0.0
#       1992-07-17 00:00:00 49000.0       115088.0     1.0        0.0
# ...

# %%
#pivot table default function is mean
pd.pivot_table(df, index=['BEDRM'])
# Out:
#                AYB     BATHRM  BLDG_NUM  CENSUS_TRACT    CMPLX_NUM  \
# BEDRM
# 0      1954.713233   1.005097  1.001322   5456.155182  2139.724030
# 1      1958.708351   1.046565  1.000496   4671.183367  2268.095380
# 2      1945.975037   1.531563  1.001402   5868.260259  2462.963974
# 3      1937.937187   1.712325  1.000242   5935.449329  2879.149725
# 4      1932.514549   2.541558  1.000281   4716.642696  2637.598109
# 5      1929.832292   3.175703  1.000435   3347.158597  2435.419355
# 6      1930.155217   3.691586  1.000647   3623.014887  2400.000000
# 7      1927.217623   4.310667  1.000000   2960.226667  1540.666667
# 8      1933.254430   4.286616  1.001263   5974.263889          NaN
# 9      1926.283333   5.186992  1.000000   4234.040650          NaN
# 10     1934.983871   5.661290  1.000000   4211.064516          NaN
# 11     1940.692308   7.230769  1.000000   5224.076923          NaN
# 12     1924.676471   5.352941  1.000000   5714.500000          NaN
# ...

# %%
#boolean values for if there's another row with the exact values in each column
dupe= df.duplicated()
df[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#Selecting rows with no missing age or gender
df[df['SALEDATE'].notnull() & df['PRICE'].notnull()]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# ...

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.fillna(0)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#Data sorting by city
df.sort_values('CITY')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 70961        70961       2          1     Forced Air  Y        1.0      7
# 70960        70960       1          1     Forced Air  N        1.0      7
# 70959        70959       3          1     Forced Air  Y        1.0      7
# 70958        70958       1          0  Hot Water Rad  N        1.0      5
# 70957        70957       3          1     Forced Air  Y        1.0      6
# 70956        70956       1          0      Warm Cool  Y        1.0      6
# 70955        70955       2          0  Hot Water Rad  N        1.0      6
# 70954        70954       1          0     Forced Air  N        1.0      5
# 70953        70953       1          0  Hot Water Rad  N        1.0      6
# 70952        70952       1          1     Forced Air  Y        1.0      6
# 70951        70951       3          1  Hot Water Rad  Y        1.0      7
# ...
